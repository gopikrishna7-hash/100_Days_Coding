# %% [markdown]
# # Design a Loan Approval System Using Credit Score, Income, and Existing Liabilities Problem Statement

# %%
# A bank approves loans based on the following criteria: 
# Credit Score: • Credit Score ≥ 750 → Eligible
# • Credit Score between 650 and 749 → Conditional Eligibility 
# • Credit Score < 650 → Rejected Income: 
# • Monthly Income ≥ ₹50,000 → Eligible 
# • Otherwise → Not Eligible Liabilities: 
# • Existing Liabilities ≤ ₹20,000 → Eligible 
# • Otherwise → Not Eligible Decision Rules: 
# • If all conditions satisfy → Approved 
# • If Credit Score is Conditional and other conditions satisfy → Approved with Conditions 
# • Otherwise → Rejected 

credit_score=int(input())
monthly_inc=int(input())
existing_lib=int(input())

credit=True
inc=True
liab=True
if credit_score >=750:
    pass
    
elif credit_score >=650 and credit_score <750:
    credit="Conditional Eligibilty"
else:
    credit =False

if monthly_inc >=50000:
    inc=True
else:
    inc=False


if existing_lib <=20000:
    pass
else:
    liab=False
if credit==True and liab and inc:
    print("Approved")
elif  credit=="Conditional Eligibilty" and liab and inc:
    print("Approved with Conditions")
else:
    print("Reject")
# Out:
#  780
#  60000
#  15000
# Approved

# %%
def loan_approval(x,y,z):
    # credit_score=int(input())
    # monthly_inc=int(input())
    # existing_lib=int(input())
    credit_score=x
    monthly_inc=y
    existing_lib=z
    
    
    
    
    if credit_score >=750:
        if monthly_inc >=50000:
            if existing_lib <=20000:
                return "Approved"
            else:
                return "Reject"
                
        else:
            return "Reject"
        
    elif credit_score >=650 and credit_score <750:
        
        if monthly_inc >=50000:
            if existing_lib <=20000:
                return "Approved with Conditions" 
            else:
                return "Reject"
                
        else:
            return "Reject"
    else:
        return "Reject"
        
    
    
res=loan_approval(700,55000,18000) 
print(res)
# Out:
# Approved with Conditions
